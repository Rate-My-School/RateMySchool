# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data/finaldf.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  UNITID                               INSTNM        CITY STABBR  \
# 0           0  100654             Alabama A & M University      Normal     AL
# 1           1  100663  University of Alabama at Birmingham  Birmingham     AL
# 2           2  100690                   Amridge University  Montgomery     AL
# 3           3  100706  University of Alabama in Huntsville  Huntsville     AL
# 4           4  100724             Alabama State University  Montgomery     AL
#
#           ZIP  REGION  PREDDEG  LOCALE   LATITUDE  ...  \
# 0       35762       5        3    12.0  34.783368  ...
# 1  35294-0110       5        3    12.0  33.505697  ...
# 2  36117-3553       5        3    12.0  32.362609  ...
# 3       35899       5        3    12.0  34.724557  ...
# 4  36104-0271       5        3    12.0  32.364317  ...
#
#    MN_EARN_WNE_INDEP1_P10  UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  \
# 0                   38100      0.0184      0.8978     0.0114      0.0014
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# UNITID                       0
# INSTNM                       0
# CITY                         0
# STABBR                       0
# ZIP                          0
# REGION                       0
# PREDDEG                      0
# LOCALE                     497
# LATITUDE                   497
# LONGITUDE                  497
# CCBASIC                    497
# CCUGPROF                   497
# CCSIZSET                   497
# ADM_RATE_ALL              4319
# PPTUG_EF                   800
# SAT_AVG_ALL               5371
# COSTT4_A                  3240
# CONTROL                      0
# TUITIONFEE_IN             2756
# TUITIONFEE_OUT            2756
# MEDIAN_HH_INC             1307
# MN_EARN_WNE_INDEP0_P10    1118
# MN_EARN_WNE_INDEP1_P10    1118
# UGDS_WHITE                 774
# UGDS_BLACK                 774
# UGDS_HISP                  774
# UGDS_ASIAN                 774
# UGDS_AIAN                  774
# UGDS_NHPI                  774
# ...

# %%
#todo: Make json for database to work with
